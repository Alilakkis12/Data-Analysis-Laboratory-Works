# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Pie Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# - In this lab, you will focus on visualizing data.
#
# - The provided dataset will be loaded into pandas for analysis.
#
# - Various pie charts will be created to:
#    - Analyze developer preferences.
#
#    - Identify technology usage trends.
#
# - The lab aims to provide insights into key variables using visual representations.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# ## Setup: Downloading and Loading the Data
# **Install the libraries**

# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 171.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 204.5 MB/s eta 0:00:00
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 162.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 142.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 90.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 138.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Download and Load the Data**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("survey-data.csv")

# Display the first few rows to understand the structure of the data
df.head()
# Out:
# --2026-07-25 06:17:10--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# 200 OKequest sent, awaiting response...
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  45.2MB/s    in 3.4s
#
# 2026-07-25 06:17:14 (44.5 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# ...

# %% [markdown]
# ### Task 1: Visualizing Data Composition with Pie Charts

# %% [markdown]
# ##### 1.1 Create a Pie Chart of the Top 5 Databases Respondents Want to Work With

# %% [markdown]
# In the survey data, the `DatabaseWantToWorkWith` column lists the databases that respondents wish to work with. Let’s visualize the top 5 most-desired databases in a pie chart.

# %%
##Write your code here
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('survey-data.csv')

# Get top 5 databases
top5 = df['DatabaseWantToWorkWith'].dropna().str.split(';').explode().str.strip().value_counts().head(5)

# Pie chart
top5.plot(kind='pie', autopct='%1.1f%%', figsize=(7,7))
plt.title('Top 5 Databases Want to Work With')
plt.ylabel('') # hide y-label
plt.show()

# %% [markdown]
# The `DevType` column lists the developer types for respondents. We’ll examine the distribution by showing the top 5 developer roles in a pie chart.

# %%
##Write your code here
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('survey-data.csv')

# Top 5 dev types
top5 = df['DevType'].dropna().str.split(';').explode().str.strip().value_counts().head(5)

# Pie chart
top5.plot(kind='pie', autopct='%1.1f%%', figsize=(7,7))
plt.title('Top 5 Developer Roles')
plt.ylabel('')
plt.show()

# %% [markdown]
# ##### 1.3 Create a pie chart for the operating systems used by respondents for professional use

# %% [markdown]
# The `OpSysProfessional` use column shows the operating systems developers use professionally. Let’s visualize the distribution of the top operating systems in a pie chart.

# %%
import pandas as pd
df = pd.read_csv('survey-data.csv')

# Sorted A-Z, one per line
for col in sorted(df.columns):
    print(col)
# Out:
# AIAcc
# AIBen
# AIChallenges
# AIComplex
# AIEthics
# AINextLess integrated
# AINextMore integrated
# AINextMuch less integrated
# AINextMuch more integrated
# AINextNo change
# AISearchDevAdmired
# AISearchDevHaveWorkedWith
# AISearchDevWantToWorkWith
# AISelect
# AISent
# AIThreat
# AIToolCurrently Using
# AIToolInterested in Using
# AIToolNot interested in Using
# Age
# BuildvsBuy
# BuyNewTool
# Check
# CodingActivities
# CompTotal
# ConvertedCompYearly
# Country
# Currency
# DatabaseAdmired
# DatabaseHaveWorkedWith
# DatabaseWantToWorkWith
# DevType
# EdLevel
# EmbeddedAdmired
# EmbeddedHaveWorkedWith
# EmbeddedWantToWorkWith
# Employment
# Frequency_1
# Frequency_2
# Frequency_3
# Frustration
# ICorPM
# Industry
# JobSat
# JobSatPoints_1
# JobSatPoints_10
# JobSatPoints_11
# JobSatPoints_4
# JobSatPoints_5
# JobSatPoints_6
# JobSatPoints_7
# JobSatPoints_8
# JobSatPoints_9
# Knowledge_1
# Knowledge_2
# Knowledge_3
# Knowledge_4
# Knowledge_5
# Knowledge_6
# Knowledge_7
# ...

# %%
##Write your code here
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('survey-data.csv')

# Distribution of OS (take top if there are many)
# The column name in this dataset is 'OpSys' - if yours is 'OpSysProfessional use' just change it
top_os = df['OpSysProfessional use'].dropna().value_counts().head(5)

top_os.plot(kind='pie', autopct='%1.1f%%', figsize=(7,7))
plt.title('Top Operating Systems for Professional Use')
plt.ylabel('')
plt.show()

print(top_os)
# Out:
# OpSysProfessional use
# Windows                                      10472
# MacOS                                         8073
# Ubuntu                                        3571
# Windows;Windows Subsystem for Linux (WSL)     2770
# Ubuntu;Windows                                1890
# Name: count, dtype: int64

# %% [markdown]
# ### Task 2: Additional Visualizations and Comparisons

# %% [markdown]
# ##### 2.1 Pie Chart for Top 5 Programming Languages Respondents Have Worked With

# %% [markdown]
# The `LanguageHaveWorkedWith` column contains the programming languages that respondents have experience with. We’ll plot a pie chart to display the composition of the top 5 languages.

# %%
##Write your code here
df["LanguageHaveWorkedWith"].value_counts()
top5=df["LanguageHaveWorkedWith"].str.split(";").explode().str.strip().value_counts().head(5)
top5.plot(kind='pie', autopct='%1.1f%%', figsize=(7,7))
plt.title('Top 5 Programming Languages Respondents Have Worked With')
plt.ylabel('')
plt.show()

# %% [markdown]
# ##### 2.2 Pie Chart for Top Collaboration Tools used in Professional Use

# %% [markdown]
# Using the `NEWCollabToolsHaveWorkedWith` column, we’ll identify and visualize the top collaboration tools respondents use in their professional work.

# %%
for d in sorted(list(df.columns)):
    if d.startswith("NEW"):
        print(d)
# Out:
# NEWCollabToolsAdmired
# NEWCollabToolsHaveWorkedWith
# NEWCollabToolsWantToWorkWith
# NEWSOSites

# %%
df["NEWCollabToolsHaveWorkedWith"].value_counts()
# Out:
# NEWCollabToolsHaveWorkedWith
# Visual Studio Code                                                                                       6154
# Visual Studio;Visual Studio Code                                                                         2546
# Notepad++;Visual Studio;Visual Studio Code                                                               1543
# IntelliJ IDEA;Visual Studio Code                                                                         1169
# Vim;Visual Studio Code                                                                                   1045
#                                                                                                          ...
# DataGrip;Jupyter Notebook/JupyterLab;PhpStorm;PyCharm;Visual Studio Code                                    1
# DataGrip;IntelliJ IDEA;Nano;PyCharm;Sublime Text;Visual Studio Code                                         1
# ...

# %%
##Write your code here
pie_c=df["NEWCollabToolsHaveWorkedWith"].dropna().str.split(";").explode().str.strip().value_counts().head(10)

pie_c.plot(kind='pie', autopct='%1.1f%%', figsize=(7,7))
plt.title('top collaboration tools respondents use in their professional work.')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Task 3: Analyzing and Interpreting Composition

# %% [markdown]
# In this task, you will create additional pie charts to analyze specific aspects of the survey data. Use `pandas` and `matplotlib` to complete each task and interpret the findings.

# %% [markdown]
# ##### 3.1 Pie Chart of `Respondents` Most Admired Programming Languages

# %% [markdown]
# The `LanguageAdmired` column lists the programming languages respondents admire most. Create a pie chart to visualize the top 5 admired languages.

# %%
##Write your code here
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('survey-data.csv')

top5 = df['LanguageAdmired'].dropna().str.split(';').explode().str.strip().value_counts().head(5)

top5.plot(kind='pie', autopct='%1.1f%%', figsize=(7,7))
plt.title('Top 5 Admired Programming Languages')
plt.ylabel('')
plt.show()

print(top5)
# Out:
# LanguageAdmired
# JavaScript    21869
# Python        20774
# SQL           20692
# HTML/CSS      19851
# TypeScript    16079
# Name: count, dtype: int64

# %% [markdown]
# ##### 3.2 Pie Chart of Tools Used for AI Development

# %% [markdown]
# Using the `AIToolCurrently` Using column, create a pie chart to visualize the top 5 tools developers are currently using for AI development.

# %%
##Write your code here
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('survey-data.csv')

col = 'AIToolCurrently Using'

top5 = df[col].dropna().str.split(';').explode().str.strip().value_counts().head(5)

top5.plot(kind='pie', autopct='%1.1f%%', figsize=(7,7))
plt.title('Top 5 AI Tools Currently Using')
plt.ylabel('')
plt.show()

print(top5)
# Out:
# AIToolCurrently Using
# Writing code                            29486
# Search for answers                      24295
# Debugging and getting help              20404
# Documenting code                        14439
# Generating content or synthetic data    12538
# Name: count, dtype: int64

# %% [markdown]
# ##### 3.3 Pie Chart for Preferred Web Frameworks

# %% [markdown]
# The `WebframeWantToWorkWith` column includes web frameworks that respondents are interested in working with. Visualize the top 5 frameworks in a pie chart.

# %%
##Write your code here
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('survey-data.csv')

top5 = df['WebframeWantToWorkWith'].dropna().str.split(';').explode().str.strip().value_counts().head(5)

top5.plot(kind='pie', autopct='%1.1f%%', figsize=(7,7))
plt.title('Top 5 Web Frameworks Want To Work With')
plt.ylabel('')
plt.show()

print(top5)
# Out:
# WebframeWantToWorkWith
# React           15404
# Node.js         14735
# Next.js          8507
# Vue.js           7604
# ASP.NET CORE     6905
# Name: count, dtype: int64

# %% [markdown]
# ##### 3.4 Pie Chart for Most Desired Embedded Technologies

# %% [markdown]
# Using the `EmbeddedWantToWorkWith` column, create a pie chart to show the top 5 most desired embedded technologies that respondents wish to work with.

# %%
##Write your code here
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('survey-data.csv')

top5 = df['EmbeddedWantToWorkWith'].dropna().str.split(';').explode().str.strip().value_counts().head(5)

top5.plot(kind='pie', autopct='%1.1f%%', figsize=(7,7))
plt.title('Top 5 Most Desired Embedded Technologies')
plt.ylabel('')
plt.show()

print(top5)
# Out:
# EmbeddedWantToWorkWith
# Rasberry Pi    9792
# Arduino        6482
# GNU GCC        5870
# CMake          4693
# Cargo          4567
# Name: count, dtype: int64

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Create pie charts to visualize developer preferences across databases, programming languages, AI tools, and cloud platforms.
# - Identify trends in technology usage, role distribution, and tool adoption through pie charts.
# - Analyze and compare data composition across various categories to gain insights into developer preferences.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
